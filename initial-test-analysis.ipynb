# %% [markdown]
# Each picture was included in the revosim program as an environment
#
# For each picture we run 5000 iterations
#
# We also considered a toroidal shape rather than having hard boundaries

# %%
#Importing required libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# d5 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over5/REvoSim_output/REvoSim_log_run_0000.txt")
d10 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over10/5000iterations/REvoSim_log_run_0000.txt")
d25 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over25/5000iterations/REvoSim_log_run_0000.txt")
d50 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over50/5000iterations/REvoSim_log_run_0000.txt")
d100 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over100/5000iterations/REvoSim_log_run_0000.txt")
d200 = pd.read_csv("/Users/gb4818/Library/CloudStorage/OneDrive-ImperialCollegeLondon/code/REvoSim_output/1over200/5000iterations/REvoSim_log_run_0000.txt")

plt.subplot(2, 1, 1)
# plt.plot(d5['Iteration_number'], d5['Species_count'], label = 'W = 5')
plt.plot(d10['Iteration_number'], d10['Species_count'], label = 'W = 10')
plt.plot(d50['Iteration_number'], d50['Species_count'], label = 'W = 50')
plt.plot(d25['Iteration_number'], d25['Species_count'], label = 'W = 25')
plt.plot(d100['Iteration_number'], d100['Species_count'], label = 'W = 100')
plt.plot(d200['Iteration_number'], d200['Species_count'], label = 'W = 200')
plt.ylabel('Species Count on grid')
plt.legend()

plt.subplot(2, 1, 2)
# plt.plot(d5['Iteration_number'], d5['Number_living_organisms'], label = 'W = 5')
plt.plot(d10['Iteration_number'], d10['Number_living_organisms'], label = 'W = 10')
plt.plot(d50['Iteration_number'], d50['Number_living_organisms'], label = 'W = 50')
plt.plot(d25['Iteration_number'], d25['Number_living_organisms'], label = 'W = 25')
plt.plot(d100['Iteration_number'], d100['Number_living_organisms'], label = 'W = 100')
plt.plot(d200['Iteration_number'], d200['Number_living_organisms'], label = 'W = 200')
plt.xlabel('Iterations')
plt.ylabel('Individuals (Abundance)')
plt.legend()

plt.tight_layout()
plt.show()
